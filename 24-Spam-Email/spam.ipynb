# %%
import pandas as pd

# %%
df = pd.read_csv('emails.csv')

# %%
df.shape
# Out:
# (5728, 2)

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (5695, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5695 entries, 0 to 5727
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    5695 non-null   object
#  1   spam    5695 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 133.5+ KB

# %%
df.head()
# Out:
#                                                 text  spam
# 0  Subject: naturally irresistible your corporate...     1
# 1  Subject: the stock trading gunslinger  fanny i...     1
# 2  Subject: unbelievable new homes made easy  im ...     1
# 3  Subject: 4 color printing special  request add...     1
# 4  Subject: do not have money , get software cds ...     1

# %%
df['spam'].value_counts()
# Out:
# spam
# 0    4327
# 1    1368
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# text    0
# spam    0
# dtype: int64

# %%
X = df['text']
y = df['spam']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %%
X_train.shape
# Out:
# (3986,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(
    lowercase=True,
    stop_words='english'
)

# %%
X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

# %%
print(X_train_tfidf.shape)
print(X_test_tfidf.shape)
# Out:
# (3986, 31300)
# (1709, 31300)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, recall_score, f1_score, confusion_matrix, classification_report

lr = LogisticRegression()
lr.fit(X_train_tfidf, y_train)
y_pred = lr.predict(X_test_tfidf)
y_pred_train = lr.predict(X_train_tfidf)

print('train')
print(accuracy_score(y_train, y_pred_train))
print(recall_score(y_train, y_pred_train))
print(f1_score(y_train, y_pred_train))
print(confusion_matrix(y_train, y_pred_train))
print(classification_report(y_train, y_pred_train))

print('test')
print(accuracy_score(y_test, y_pred))
print(recall_score(y_test, y_pred))
print(f1_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# train
# 0.9934771700953337
# 0.9749216300940439
# 0.9862579281183932
# [[3027    2]
#  [  24  933]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      3029
#            1       1.00      0.97      0.99       957
#
#     accuracy                           0.99      3986
#    macro avg       0.99      0.99      0.99      3986
# weighted avg       0.99      0.99      0.99      3986
#
# test
# 0.9806904622586308
# 0.927007299270073
# 0.9584905660377359
# [[1295    3]
#  [  30  381]]
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1298
#            1       0.99      0.93      0.96       411
#
#     accuracy                           0.98      1709
#    macro avg       0.98      0.96      0.97      1709
# weighted avg       0.98      0.98      0.98      1709

# %%
from sklearn.naive_bayes import  GaussianNB

naive = GaussianNB()
naive.fit(X_train_tfidf.toarray(), y_train)
y_pred = naive.predict(X_test_tfidf.toarray())
y_pred_train = naive.predict(X_train_tfidf.toarray())

print('train')
print(accuracy_score(y_train, y_pred_train))
print(recall_score(y_train, y_pred_train))
print(f1_score(y_train, y_pred_train))
print(confusion_matrix(y_train, y_pred_train))
print(classification_report(y_train, y_pred_train))

print('test')
print(accuracy_score(y_test, y_pred))
print(recall_score(y_test, y_pred))
print(f1_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# train
# 0.9977420973406924
# 1.0
# 0.9953198127925117
# [[3020    9]
#  [   0  957]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3029
#            1       0.99      1.00      1.00       957
#
#     accuracy                           1.00      3986
#    macro avg       1.00      1.00      1.00      3986
# weighted avg       1.00      1.00      1.00      3986
#
# test
# 0.9531889994148625
# 0.8491484184914841
# 0.897172236503856
# [[1280   18]
#  [  62  349]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      1298
#            1       0.95      0.85      0.90       411
#
#     accuracy                           0.95      1709
#    macro avg       0.95      0.92      0.93      1709
# weighted avg       0.95      0.95      0.95      1709

# %%
from sklearn.naive_bayes import  GaussianNB

naive = GaussianNB()
naive.fit(X_train_tfidf, y_train)
y_pred = naive.predict(X_test_tfidf)
y_pred_train = naive.predict(X_train_tfidf)

print('train')
print(accuracy_score(y_train, y_pred_train))
print(recall_score(y_train, y_pred_train))
print(f1_score(y_train, y_pred_train))
print(confusion_matrix(y_train, y_pred_train))
print(classification_report(y_train, y_pred_train))

print('test')
print(accuracy_score(y_test, y_pred))
print(recall_score(y_test, y_pred))
print(f1_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[98], line 4
#       1 from sklearn.naive_bayes import  GaussianNB
#       3 naive = GaussianNB()
# ----> 4 naive.fit(X_train_tfidf, y_train)
#       5 y_pred = naive.predict(X_test_tfidf)
#       6 y_pred_train = naive.predict(X_train_tfidf)
#
# File ~/miniconda3/lib/python3.13/site-packages/sklearn/base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# -> 1403     return fit_method(estimator, *args, **kwargs)
#
# File ~/miniconda3/lib/python3.13/site-packages/sklearn/naive_bayes.py:279, in GaussianNB.fit(self, X, y, sample_weight)
#     277 y = validate_data(self, y=y)
#     278 xp_y, _ = get_namespace(y)
# --> 279 return self._partial_fit(
#     280     X, y, xp_y.unique_values(y), _refit=True, sample_weight=sample_weight
#     281 )
#
# File ~/miniconda3/lib/python3.13/site-packages/sklearn/naive_bayes.py:440, in GaussianNB._partial_fit(self, X, y, classes, _refit, sample_weight)
#     437     self.classes_ = None
#     439 first_call = _check_partial_fit_first_call(self, classes)
# --> 440 X, y = validate_data(self, X, y, reset=first_call)
#     441 xp, _, device_ = get_namespace_and_device(X)
#     442 float_dtype = _find_matching_floating_dtype(X, xp=xp)
#
# File ~/miniconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:3055, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    3053         y = check_array(y, input_name="y", **check_y_params)
#    3054     else:
# -> 3055         X, y = check_X_y(X, y, **check_params)
#    3056     out = X, y
#    3058 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~/miniconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:1327, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1322         estimator_name = _check_estimator_name(estimator)
#    1323     raise ValueError(
#    1324         f"{estimator_name} requires y to be passed, but the target y is None"
#    1325     )
# -> 1327 X = check_array(
#    1328     X,
#    1329     accept_sparse=accept_sparse,
#    1330     accept_large_sparse=accept_large_sparse,
#    1331     dtype=dtype,
#    1332     order=order,
#    1333     copy=copy,
#    1334     force_writeable=force_writeable,
#    1335     ensure_all_finite=ensure_all_finite,
#    1336     ensure_2d=ensure_2d,
#    1337     allow_nd=allow_nd,
#    1338     ensure_min_samples=ensure_min_samples,
#    1339     ensure_min_features=ensure_min_features,
#    1340     estimator=estimator,
#    1341     input_name="X",
#    1342 )
#    1344 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1346 check_consistent_length(X, y)
#
# File ~/miniconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:994, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     992 if sp.issparse(array):
#     993     _ensure_no_complex_data(array)
# --> 994     array = _ensure_sparse_format(
#     995         array,
#     996         accept_sparse=accept_sparse,
#     997         dtype=dtype,
#     998         copy=copy,
#     999         ensure_all_finite=ensure_all_finite,
#    1000         accept_large_sparse=accept_large_sparse,
#    1001         estimator_name=estimator_name,
#    1002         input_name=input_name,
#    1003     )
#    1004     if ensure_2d and array.ndim < 2:
#    1005         raise ValueError(
#    1006             f"Expected 2D input, got input with shape {array.shape}.\n"
#    1007             "Reshape your data either using array.reshape(-1, 1) if "
#    1008             "your data has a single feature or array.reshape(1, -1) "
#    1009             "if it contains a single sample."
#    1010         )
#
# File ~/miniconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:600, in _ensure_sparse_format(sparse_container, accept_sparse, dtype, copy, ensure_all_finite, accept_large_sparse, estimator_name, input_name)
#     598 if accept_sparse is False:
#     599     padded_input = " for " + input_name if input_name else ""
# --> 600     raise TypeError(
#     601         f"Sparse data was passed{padded_input}, but dense data is required. "
#     602         "Use '.toarray()' to convert to a dense numpy array."
#     603     )
#     604 elif isinstance(accept_sparse, (list, tuple)):
#     605     if len(accept_sparse) == 0:
#
# TypeError: Sparse data was passed for X, but dense data is required. Use '.toarray()' to convert to a dense numpy array.

# %%
from sklearn.neighbors import  KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=4)
knn.fit(X_train_tfidf.toarray(), y_train)
y_pred = knn.predict(X_test_tfidf.toarray())
y_pred_train = knn.predict(X_train_tfidf.toarray())

print('train')
print(accuracy_score(y_train, y_pred_train))
print(recall_score(y_train, y_pred_train))
print(f1_score(y_train, y_pred_train))
print(confusion_matrix(y_train, y_pred_train))
print(classification_report(y_train, y_pred_train))

print('test')
print(accuracy_score(y_test, y_pred))
print(recall_score(y_test, y_pred))
print(f1_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# train
# 0.9811841445057702
# 0.9247648902821317
# 0.959349593495935
# [[3026    3]
#  [  72  885]]
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      3029
#            1       1.00      0.92      0.96       957
#
#     accuracy                           0.98      3986
#    macro avg       0.99      0.96      0.97      3986
# weighted avg       0.98      0.98      0.98      3986
#
# test
# 0.9748390871854886
# 0.9075425790754258
# 0.9455006337135615
# [[1293    5]
#  [  38  373]]
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      1298
#            1       0.99      0.91      0.95       411
#
#     accuracy                           0.97      1709
#    macro avg       0.98      0.95      0.96      1709
# weighted avg       0.98      0.97      0.97      1709
