# %%
import pandas as pd

# %%
df = pd.read_excel('yahoo_data.xlsx')

# %%
df.head()
# Out:
#            Date      Open      High       Low    Close*  Adj Close**  \
# 0  Apr 28, 2023  33797.43  34104.56  33728.40  34098.16     34098.16
# 1  Apr 27, 2023  33381.66  33859.75  33374.65  33826.16     33826.16
# 2  Apr 26, 2023  33596.34  33645.83  33235.85  33301.87     33301.87
# 3  Apr 25, 2023  33828.34  33875.49  33525.39  33530.83     33530.83
# 4  Apr 24, 2023  33805.04  33891.15  33726.09  33875.40     33875.40
#
#       Volume
# 0  354310000
# 1  343240000
# 2  321170000
# 3  297880000
# 4  252020000

# %%
df.shape
# Out:
# (1258, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         1258 non-null   object
#  1   Open         1258 non-null   float64
#  2   High         1258 non-null   float64
#  3   Low          1258 non-null   float64
#  4   Close*       1258 non-null   float64
#  5   Adj Close**  1258 non-null   float64
#  6   Volume       1258 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 68.9+ KB

# %%
df.isnull().sum()
# Out:
# Date           0
# Open           0
# High           0
# Low            0
# Close*         0
# Adj Close**    0
# Volume         0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df.describe()
# Out:
#                Open          High           Low        Close*   Adj Close**  \
# count   1258.000000   1258.000000   1258.000000   1258.000000   1258.000000
# mean   29595.823045  29776.945739  29402.432226  29599.361677  29599.361677
# std     4006.078299   4009.007573   4004.949066   4007.468822   4007.468822
# min    19028.360000  19121.010000  18213.650000  18591.930000  18591.930000
# 25%    26041.267500  26163.155000  25877.872500  26027.120000  26027.120000
# 50%    29201.410000  29335.685000  28996.500000  29199.460000  29199.460000
# 75%    33604.027500  33825.445000  33346.827500  33600.342500  33600.342500
# max    36722.600000  36952.650000  36636.000000  36799.650000  36799.650000
#
#              Volume
# count  1.258000e+03
# mean   3.450636e+08
# std    1.069142e+08
# min    8.615000e+07
# 25%    2.773125e+08
# 50%    3.247250e+08
# 75%    3.875100e+08
# max    9.159900e+08

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         1258 non-null   datetime64[ns]
#  1   Open         1258 non-null   float64
#  2   High         1258 non-null   float64
#  3   Low          1258 non-null   float64
#  4   Close*       1258 non-null   float64
#  5   Adj Close**  1258 non-null   float64
#  6   Volume       1258 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 68.9 KB

# %%
df = df.sort_values("Date")

# %%
df = df.reset_index(drop=True)

# %%
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day
df['DayOfWeek'] = df['Date'].dt.dayofweek

# %%
df.head()
# Out:
#         Date      Open      High       Low    Close*  Adj Close**     Volume  \
# 0 2018-05-01  24117.29  24117.29  23808.19  24099.05     24099.05  380070000
# 1 2018-05-02  24097.63  24185.52  23886.30  23924.98     23924.98  385350000
# 2 2018-05-03  23836.23  23996.15  23531.31  23930.15     23930.15  389240000
# 3 2018-05-04  23865.22  24333.35  23778.87  24262.51     24262.51  329480000
# 4 2018-05-07  24317.66  24479.45  24263.42  24357.32     24357.32  307670000
#
#    Year  Month  Day  DayOfWeek
# 0  2018      5    1          1
# 1  2018      5    2          2
# 2  2018      5    3          3
# 3  2018      5    4          4
# 4  2018      5    7          0

# %%
df.head()
# Out:
#         Date      Open      High       Low    Close*  Adj Close**     Volume  \
# 0 2018-05-01  24117.29  24117.29  23808.19  24099.05     24099.05  380070000
# 1 2018-05-02  24097.63  24185.52  23886.30  23924.98     23924.98  385350000
# 2 2018-05-03  23836.23  23996.15  23531.31  23930.15     23930.15  389240000
# 3 2018-05-04  23865.22  24333.35  23778.87  24262.51     24262.51  329480000
# 4 2018-05-07  24317.66  24479.45  24263.42  24357.32     24357.32  307670000
#
#    Year  Month  Day  DayOfWeek
# 0  2018      5    1          1
# 1  2018      5    2          2
# 2  2018      5    3          3
# 3  2018      5    4          4
# 4  2018      5    7          0

# %%
print("Start Date:", df["Date"].min())
print("End Date:", df["Date"].max())
# Out:
# Start Date: 2018-05-01 00:00:00
# End Date: 2023-04-28 00:00:00

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))
plt.plot(df["Date"], df["Close*"])
plt.xlabel("Date")
plt.ylabel("Closing Price")
plt.title("Stock Closing Price Over Time")
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))
plt.plot(df["Date"], df["Volume"])
plt.xlabel("Date")
plt.ylabel("Volume")
plt.title("trading volume Price Over Time")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))

plt.plot(df["Date"], df["Open"], label="Open")
plt.plot(df["Date"], df["High"], label="High")
plt.plot(df["Date"], df["Low"], label="Low")
plt.plot(df["Date"], df["Close*"], label="Close")

plt.xlabel("Date")
plt.ylabel("Price")
plt.title("Stock Price Analysis")
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(12,8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt='.2f')
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.boxplot(df['Close*'])
plt.title('closing distribution')
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.boxplot(df['Volume'].dropna())
plt.title('volume distribution')
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.hist(df['Close*'], bins=50)
plt.xlabel('Close price')
plt.ylabel('frequency')
plt.title('volume distribution')
plt.show()

# %%
df["Daily_Return"] = df["Close*"].pct_change()

# %%
plt.figure(figsize=(12, 5))
plt.plot(df["Date"], df["Daily_Return"])
plt.xlabel("Date")
plt.ylabel("Daily Return")
plt.title("Daily Stock Returns")
plt.xticks(rotation=45)
plt.show()

# %%
df = df.sort_values('Date').reset_index(drop=True)

df['Close_lag_1'] = df['Close*'].shift(1)
df['Close_lag_2'] = df['Close*'].shift(2)
df['Close_lag_3'] = df['Close*'].shift(3)
df['Close_lag_5'] = df['Close*'].shift(5)
df['Close_lag_6'] = df['Close*'].shift(6)
df['Close_lag_7'] = df['Close*'].shift(7)

# %%
df['MA_7'] = df['Close*'].rolling(7).mean()
df['MA_21'] = df['Close*'].rolling(21).mean()
df['MA_50'] = df['Close*'].rolling(50).mean()

# %%
df.head()
# Out:
#         Date      Open      High       Low    Close*  Adj Close**     Volume  \
# 0 2018-05-01  24117.29  24117.29  23808.19  24099.05     24099.05  380070000
# 1 2018-05-02  24097.63  24185.52  23886.30  23924.98     23924.98  385350000
# 2 2018-05-03  23836.23  23996.15  23531.31  23930.15     23930.15  389240000
# 3 2018-05-04  23865.22  24333.35  23778.87  24262.51     24262.51  329480000
# 4 2018-05-07  24317.66  24479.45  24263.42  24357.32     24357.32  307670000
#
#    Year  Month  Day  ...  Daily_Return  Close_lag_1  Close_lag_2  Close_lag_3  \
# 0  2018      5    1  ...           NaN          NaN          NaN          NaN
# 1  2018      5    2  ...     -0.007223     24099.05          NaN          NaN
# 2  2018      5    3  ...      0.000216     23924.98     24099.05          NaN
# 3  2018      5    4  ...      0.013889     23930.15     23924.98     24099.05
# 4  2018      5    7  ...      0.003908     24262.51     23930.15     23924.98
#
#    Close_lag_5  Close_lag_6  Close_lag_7  MA_7  MA_21  MA_50
# 0          NaN          NaN          NaN   NaN    NaN    NaN
# 1          NaN          NaN          NaN   NaN    NaN    NaN
# 2          NaN          NaN          NaN   NaN    NaN    NaN
# 3          NaN          NaN          NaN   NaN    NaN    NaN
# 4          NaN          NaN          NaN   NaN    NaN    NaN
#
# [5 rows x 21 columns]

# %%
# Returns
df["Daily_Return"] = df["Close*"].pct_change()
df["Weekly_Return"] = df["Close*"].pct_change(5)

# Volatility
df["Volatility_7"] = df["Daily_Return"].rolling(7).std()
df["Volatility_21"] = df["Daily_Return"].rolling(21).std()

# Price features
df["Price_Range"] = df["High"] - df["Low"]
df["Price_Range_Pct"] = (df["High"] - df["Low"]) / df["Close*"]

# Open-Close features
df["Open_Close_Diff"] = df["Close*"] - df["Open"]
df["Open_Close_Pct"] = (df["Close*"] - df["Open"]) / df["Open"]

# Volume features
df["Volume_Lag_1"] = df["Volume"].shift(1)
df["Volume_MA_7"] = df["Volume"].rolling(7).mean()

# Target: next day's closing price
df["Target"] = df["Close*"].shift(-1)

# Remove NaN
df = df.dropna().reset_index(drop=True)

print(df.shape)
print(df.head())
# Out:
# (1208, 31)
#         Date      Open      High       Low    Close*  Adj Close**     Volume  \
# 0 2018-07-11  24789.48  24815.16  24663.82  24700.45     24700.45  237370000
# 1 2018-07-12  24802.90  24939.97  24802.90  24924.89     24924.89  233150000
# 2 2018-07-13  24926.07  25043.21  24890.06  25019.41     25019.41  255520000
# 3 2018-07-16  25025.58  25072.41  24979.64  25064.36     25064.36  231270000
# 4 2018-07-17  25033.92  25155.39  24989.61  25119.89     25119.89  250450000
#
#    Year  Month  Day  ...  Weekly_Return  Volatility_7  Volatility_21  \
# 0  2018      7   11  ...       0.021743      0.007555       0.006636
# 1  2018      7   12  ...       0.023326      0.007916       0.007002
# 2  2018      7   13  ...       0.023018      0.006852       0.007005
# 3  2018      7   16  ...       0.011615      0.006834       0.007018
# 4  2018      7   17  ...       0.008035      0.006872       0.006997
#
#    Price_Range  Price_Range_Pct  Open_Close_Diff  Open_Close_Pct  \
# 0       151.34         0.006127           -89.03       -0.003591
# 1       137.07         0.005499           121.99        0.004918
# 2       153.15         0.006121            93.34        0.003745
# 3        92.77         0.003701            38.78        0.001550
# 4       165.78         0.006600            85.97        0.003434
#
#    Volume_Lag_1   Volume_MA_7    Target
# 0   235040000.0  2.250257e+08  24924.89
# 1   237370000.0  2.234600e+08  25019.41
# 2   233150000.0  2.369686e+08  25064.36
# 3   255520000.0  2.360543e+08  25119.89
# 4   231270000.0  2.404829e+08  25199.29
#
# [5 rows x 31 columns]

# %%
df["Target"] = df["Close*"].shift(-1)
df = df.dropna()

# %%
features = [
    "Open",
    "High",
    "Low",
    "Close*",
    "Volume",
    "Close_lag_1",
    "Close_lag_2",
    "Close_lag_3",
    "Close_lag_5",
    "Close_lag_7",
    "MA_7",
    "MA_21",
    "MA_50",
    "Daily_Return",
    "Weekly_Return",
    "Volatility_7",
    "Volatility_21",
    "Price_Range",
    "Price_Range_Pct",
    "Open_Close_Diff",
    "Open_Close_Pct",
    "Volume_Lag_1",
    "Volume_MA_7"
]

X = df[features]
y = df["Target"]

# %%
# Chronological Train-Test Split

train_size =  int(len(df)*0.8)
X_train =X.iloc[:train_size]
X_test =X.iloc[train_size:]

y_train = y.iloc[:train_size]
y_test = y.iloc[train_size:]

# %%
X_train.shape
# Out:
# (965, 23)

# %%
X_test.shape
# Out:
# (242, 23)

# %%
df.isnull().sum()
# Out:
# Date               0
# Open               0
# High               0
# Low                0
# Close*             0
# Adj Close**        0
# Volume             0
# Year               0
# Month              0
# Day                0
# DayOfWeek          0
# Daily_Return       0
# Close_lag_1        0
# Close_lag_2        0
# Close_lag_3        0
# Close_lag_5        0
# Close_lag_6        0
# Close_lag_7        0
# MA_7               0
# MA_21              0
# MA_50              0
# Weekly_Return      0
# Volatility_7       0
# Volatility_21      0
# Price_Range        0
# Price_Range_Pct    0
# Open_Close_Diff    0
# Open_Close_Pct     0
# Volume_Lag_1       0
# Volume_MA_7        0
# Target             0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scale = scaler.fit_transform(X_train)
X_test_scale = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, root_mean_squared_error, r2_score


lr = LinearRegression()
lr.fit(X_train_scale, y_train)

y_pred = lr.predict(X_test_scale)
y_pred_train = lr.predict(X_train_scale)

print('train')

print(root_mean_squared_error(y_train, y_pred_train))
print(mean_squared_error(y_train, y_pred_train))
print(mean_absolute_error(y_train, y_pred_train))
print(r2_score(y_train, y_pred_train))

print('test')
print(root_mean_squared_error(y_test, y_pred))
print(mean_squared_error(y_test, y_pred))
print(mean_absolute_error(y_test, y_pred))
print(r2_score(y_test, y_pred))
# Out:
# train
# 341.2034160234057
# 116419.77110604125
# 233.53592014208698
# 0.9931066681745024
# test
# 374.7511270218837
# 140438.40720417202
# 287.38486896617565
# 0.9233171905131374

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))

plt.plot(y_test.values, label="Actual")
plt.plot(y_pred, label="Predicted")

plt.xlabel("Time")
plt.ylabel("Closing Price")
plt.title("Actual vs Predicted Stock Price")
plt.legend()

plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor 


rf = RandomForestRegressor(n_estimators=101, max_depth=3)
rf.fit(X_train_scale, y_train)

y_pred = rf.predict(X_test_scale)
y_pred_train = rf.predict(X_train_scale)

print('train')

print(root_mean_squared_error(y_train, y_pred_train))
print(mean_squared_error(y_train, y_pred_train))
print(mean_absolute_error(y_train, y_pred_train))
print(r2_score(y_train, y_pred_train))

print('test')
print(root_mean_squared_error(y_test, y_pred))
print(mean_squared_error(y_test, y_pred))
print(mean_absolute_error(y_test, y_pred))
print(r2_score(y_test, y_pred))
# Out:
# train
# 512.5113737151383
# 262667.90818737826
# 355.7370380558908
# 0.9844471687768938
# test
# 596.3836079880585
# 355673.40787685424
# 484.31835710969085
# 0.8057936093214695

# %%
from sklearn.ensemble import GradientBoostingRegressor 
from sklearn.model_selection import GridSearchCV

gb = GradientBoostingRegressor()
param = [{
    'n_estimators':[50,100,200],
    'max_depth':[2,3,4],
    'learning_rate':[0.05,0.01]
}]
grid = GridSearchCV(estimator=gb, param_grid=param, cv=5, n_jobs=3)
grid.fit(X_train_scale, y_train)

gb.fit(X_train_scale, y_train)

y_pred = gb.predict(X_test_scale)
y_pred_train = gb.predict(X_train_scale)

print(grid.best_params_)
print('train')

print(root_mean_squared_error(y_train, y_pred_train))
print(mean_squared_error(y_train, y_pred_train))
print(mean_absolute_error(y_train, y_pred_train))
print(r2_score(y_train, y_pred_train))

print('test')
print(root_mean_squared_error(y_test, y_pred))
print(mean_squared_error(y_test, y_pred))
print(mean_absolute_error(y_test, y_pred))
print(r2_score(y_test, y_pred))
# Out:
# {'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 200}
# train
# 198.05237083123117
# 39224.74159187151
# 149.77011504989912
# 0.9976774635700333
# test
# 495.42658380373814
# 245447.49993944235
# 377.0771901600039
# 0.8659796543439875

# %%
from xgboost import XGBRegressor 
from sklearn.model_selection import GridSearchCV


xg = XGBRegressor()
param = [{
    'n_estimators':[50,100,200],
    'max_depth':[2,3,4]
}]
grid = GridSearchCV(estimator=xg, param_grid=param, cv=5, n_jobs=3)
grid.fit(X_train_scale, y_train)

y_pred = grid.predict(X_test_scale)
y_pred_train = grid.predict(X_train_scale)

print('train')

print(root_mean_squared_error(y_train, y_pred_train))
print(mean_squared_error(y_train, y_pred_train))
print(mean_absolute_error(y_train, y_pred_train))
print(r2_score(y_train, y_pred_train))

print('test')
print(root_mean_squared_error(y_test, y_pred))
print(mean_squared_error(y_test, y_pred))
print(mean_absolute_error(y_test, y_pred))
print(r2_score(y_test, y_pred))
# Out:
# train
# 278.8030440842416
# 77731.13739063957
# 210.13961504209843
# 0.9953974611175025
# test
# 548.8728767565065
# 301261.4348389631
# 426.08119544163253
# 0.8355038790783951
